# %% [markdown]
# # Lab 3 · 6개 모델 한 번에 비교 (MLP·Conv1D·RNN 계열)
#
# - 이 노트북은 한 세션에서 끝까지 이어서 실행합니다.
# - 6개 모델을 전부 학습해서 바로 비교합니다.
#
# 1. Flatten, GAP, Conv1D — 지난 시간 복습
# 2. SimpleRNN, LSTM, GRU — 이번 시간 새로 배우는 것
# 3. 6개 모델 성능 비교
#
# > 6개 모델을 전부 학습하므로 지난 실습보다 시간이 더 걸립니다. 중간에 끊기지 않도록 한 번에 위에서
# > 아래로 실행하세요.

# %%
# !pip install -q koreanize-matplotlib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## 1. 저장된 파일 불러오기

# %%
import urllib.request

url = "https://raw.githubusercontent.com/hongsukyi/DL4NLP/main/notebooks/data.npz"
urllib.request.urlretrieve(url, "data.npz")
# Out:
# ('data.npz', <http.client.HTTPMessage at 0x27cac9ba550>)

# %%
data = np.load("data.npz", allow_pickle=True)

ids  = data["input_ids"]
mask = data["attention_mask"]
y    = data["labels"]

idx_tr  = data["train_idx"]
idx_val = data["val_idx"]
idx_te  = data["test_idx"]

vocab_size = int(data["vocab_size"])
max_len    = int(data["max_len"])
n_cls      = int(data["num_classes"])
classes    = data["class_names"].tolist()

X_tr,  M_tr,  y_tr  = ids[idx_tr],  mask[idx_tr],  y[idx_tr]
X_val, M_val, y_val = ids[idx_val], mask[idx_val], y[idx_val]
X_te,  M_te,  y_te  = ids[idx_te],  mask[idx_te],  y[idx_te]

print("train/val/test:", len(X_tr), len(X_val), len(X_te))
print("classes:", classes)
# Out:
# train/val/test: 1680 360 360
# classes: ['면접', '학교', '협상']

# %% [markdown]
# ## 2. 공통 준비물
#
# `res` 딕셔너리에 6개 모델의 결과를 전부 담아둡니다. **파일로 저장하지 않고, 이 노트북이 끝날 때까지
# 메모리에 계속 들고 있다가** 마지막 비교 절에서 바로 씁니다.

# %%
res = {}   # 6개 모델 결과를 여기 전부 모음 

dim   = 64  # 임베딩 크기
units = 64  # RNN 은닉상태 크기

def embed(inp, inm):
    """MLP 계열(Flatten/GAP/Conv1D)용: PAD 자리를 0으로 만든 임베딩"""
    x = layers.Embedding(vocab_size, dim)(inp)
    mf = layers.Lambda(lambda t: tf.cast(t, tf.float32)[..., None])(inm)
    return layers.Multiply()([x, mf])

def embed_mask(inp, inm):
    """RNN 계열(SimpleRNN/LSTM/GRU)용: PAD 자리를 0으로 만들고 Masking까지 적용"""
    x = embed(inp, inm)
    return layers.Masking(mask_value=0.0)(x)

def fit_model(model, name):
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    es = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=True)
    h = model.fit(
        [X_tr, M_tr], y_tr, validation_data=([X_val, M_val], y_val),
        batch_size=32, epochs=30, callbacks=[es], verbose=2,
    )
    return h

def show_result(model, h, name):
    fig, ax = plt.subplots(1, 2, figsize=(8, 3))
    ax[0].plot(h.history["loss"], label="train"); ax[0].plot(h.history["val_loss"], label="val")
    ax[0].set_title(f"{name} - Loss"); ax[0].legend()
    ax[1].plot(h.history["accuracy"], label="train"); ax[1].plot(h.history["val_accuracy"], label="val")
    ax[1].set_title(f"{name} - Accuracy"); ax[1].legend()
    plt.tight_layout(); plt.show()

    pred = model.predict([X_te, M_te], verbose=0).argmax(axis=1)
    acc = (pred == y_te).mean()
    res[name] = {
        "loss": h.history["loss"], "val_loss": h.history["val_loss"],
        "acc": h.history["accuracy"], "val_acc": h.history["val_accuracy"],
        "pred": pred.tolist(), "test_acc": float(acc),
    }
    print(f"[{name}] Test Accuracy: {acc:.3f}")

    cm = confusion_matrix(y_te, pred)
    plt.figure(figsize=(4, 4))
    plt.imshow(cm, cmap="Blues")
    plt.xticks(range(n_cls), classes); plt.yticks(range(n_cls), classes)
    for i in range(n_cls):
        for j in range(n_cls):
            plt.text(j, i, cm[i, j], ha="center", va="center")
    plt.title(f"{name} - Confusion Matrix"); plt.xlabel("예측"); plt.ylabel("정답")
    plt.tight_layout(); plt.show()

    feat_model = keras.Model(model.input, model.get_layer("feat").output)
    feat = feat_model.predict([X_te, M_te], verbose=0)
    xy = TSNE(n_components=2, random_state=SEED, init="pca", perplexity=30, n_jobs=1).fit_transform(feat)

    plt.figure(figsize=(5, 3))
    for c in range(n_cls):
        m = y_te == c
        plt.scatter(xy[m, 0], xy[m, 1], s=12, label=classes[c])
    plt.title(f"{name} - t-SNE"); plt.legend()
    plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3. 모델 1~3 · Flatten / GAP / Conv1D (복습)
#
# 지난 실습(Lab2)에서 배운 세 모델을 이 노트북 안에서 다시 학습시킵니다. 파일을 주고받지 않고
# **이 세션 안에서 바로 비교**하기 위해서입니다.

# %%
def build_flatten():
    inp = keras.Input((max_len,), dtype="int32", name="input_ids")
    inm = keras.Input((max_len,), dtype="int32", name="attention_mask")

    x = embed(inp, inm)
    x = layers.Flatten()(x)
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)

    return keras.Model([inp, inm], out)

flat_model = build_flatten()
# Out:
# WARNING:tensorflow:From C:\Users\hongs\anaconda3\envs\qml44\Lib\site-packages\keras\src\backend\tensorflow\core.py:233: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
def build_gap():
    inp = keras.Input((max_len,), dtype="int32", name="input_ids")
    inm = keras.Input((max_len,), dtype="int32", name="attention_mask")

    x = embed(inp, inm)
    s = layers.Lambda(lambda t: tf.reduce_sum(t, axis=1))(x)
    c = layers.Lambda(lambda m: tf.maximum(
            tf.reduce_sum(tf.cast(m, tf.float32), axis=1, keepdims=True), 1.0))(inm)
    avg = layers.Lambda(lambda t: t[0] / t[1])([s, c])

    x = layers.Dense(64, activation="relu")(avg)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)

    return keras.Model([inp, inm], out)

gap_model = build_gap()

# %%
def build_conv1d():
    inp = keras.Input((max_len,), dtype="int32", name="input_ids")
    inm = keras.Input((max_len,), dtype="int32", name="attention_mask")

    x = embed(inp, inm)
    x = layers.Conv1D(64, kernel_size=3, padding="same", activation="relu")(x)

    bias = layers.Lambda(lambda m: (1.0 - tf.cast(m, tf.float32))[..., None] * -1e9)(inm)
    x = layers.Add()([x, bias])
    x = layers.GlobalMaxPooling1D()(x)

    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)

    return keras.Model([inp, inm], out)

conv_model = build_conv1d()

# %% [markdown]
# ## 4. 모델 4~6 · SimpleRNN / LSTM / GRU

# %%
def build_simplernn():
    inp = keras.Input((max_len,))
    inm = keras.Input((max_len,))

    x = embed_mask(inp, inm)
    x = layers.SimpleRNN(units)(x)
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)

    return keras.Model([inp, inm], out)

rnn_model = build_simplernn()

# %%
def build_lstm():
    inp = keras.Input((max_len,))
    inm = keras.Input((max_len,))

    x = embed_mask(inp, inm)
    x = layers.LSTM(units)(x)
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)

    return keras.Model([inp, inm], out)

lstm_model = build_lstm()

# %%
def build_gru():
    inp = keras.Input((max_len,))
    inm = keras.Input((max_len,))

    x = embed_mask(inp, inm)
    x = layers.GRU(units)(x)
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)

    return keras.Model([inp, inm], out)

gru_model = build_gru()

# %%
h_rnn = fit_model(rnn_model, "SimpleRNN")
show_result(rnn_model, h_rnn, "SimpleRNN")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/30
# 53/53 - 2s - 39ms/step - accuracy: 0.5060 - loss: 0.9956 - val_accuracy: 0.6361 - val_loss: 0.8189
# Epoch 2/30
# 53/53 - 0s - 9ms/step - accuracy: 0.8643 - loss: 0.3785 - val_accuracy: 0.7306 - val_loss: 0.7279
# Epoch 3/30
# 53/53 - 1s - 10ms/step - accuracy: 0.9571 - loss: 0.1329 - val_accuracy: 0.7917 - val_loss: 0.6828
# Epoch 4/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9929 - loss: 0.0409 - val_accuracy: 0.7833 - val_loss: 0.7207
# Epoch 5/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9958 - loss: 0.0148 - val_accuracy: 0.7556 - val_loss: 1.0730
# Epoch 6/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.7750 - val_loss: 0.8642
# Epoch 7/30
# 53/53 - 0s - 8ms/step - accuracy: 0.9994 - loss: 0.0031 - val_accuracy: 0.7750 - val_loss: 0.8508
# Epoch 8/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 9.5923e-04 - val_accuracy: 0.7833 - val_loss: 0.9163
# Epoch 9/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7583 - val_loss: 0.9905
# Epoch 10/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7694 - val_loss: 0.9478
# Epoch 11/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 3.0918e-04 - val_accuracy: 0.7750 - val_loss: 0.9878
# Epoch 12/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 2.2269e-04 - val_accuracy: 0.7833 - val_loss: 1.0118
# Epoch 13/30
# 53/53 - 0s - 8ms/step - accuracy: 1.0000 - loss: 1.7606e-04 - val_accuracy: 0.7778 - val_loss: 1.0323
# [SimpleRNN] Test Accuracy: 0.808

# %%
h_lstm = fit_model(lstm_model, "LSTM")
show_result(lstm_model, h_lstm, "LSTM")
# Out:
# Epoch 1/30
# 53/53 - 2s - 43ms/step - accuracy: 0.4685 - loss: 1.0334 - val_accuracy: 0.5667 - val_loss: 0.8827
# Epoch 2/30
# 53/53 - 1s - 14ms/step - accuracy: 0.6935 - loss: 0.6347 - val_accuracy: 0.6389 - val_loss: 0.8328
# Epoch 3/30
# 53/53 - 1s - 13ms/step - accuracy: 0.8560 - loss: 0.3685 - val_accuracy: 0.7389 - val_loss: 0.7653
# Epoch 4/30
# 53/53 - 1s - 14ms/step - accuracy: 0.9423 - loss: 0.1626 - val_accuracy: 0.7472 - val_loss: 0.8483
# Epoch 5/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9637 - loss: 0.1158 - val_accuracy: 0.7472 - val_loss: 0.8586
# Epoch 6/30
# 53/53 - 1s - 14ms/step - accuracy: 0.9762 - loss: 0.0738 - val_accuracy: 0.7611 - val_loss: 0.7984
# Epoch 7/30
# 53/53 - 1s - 13ms/step - accuracy: 0.9940 - loss: 0.0227 - val_accuracy: 0.7639 - val_loss: 0.9984
# Epoch 8/30
# 53/53 - 1s - 13ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 0.7694 - val_loss: 1.0930
# Epoch 9/30
# 53/53 - 1s - 13ms/step - accuracy: 0.9940 - loss: 0.0340 - val_accuracy: 0.7833 - val_loss: 0.9588
# Epoch 10/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9958 - loss: 0.0148 - val_accuracy: 0.7722 - val_loss: 1.0151
# Epoch 11/30
# 53/53 - 1s - 12ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7806 - val_loss: 1.1466
# Epoch 12/30
# 53/53 - 1s - 13ms/step - accuracy: 1.0000 - loss: 7.4021e-04 - val_accuracy: 0.7917 - val_loss: 1.2986
# Epoch 13/30
# 53/53 - 1s - 12ms/step - accuracy: 1.0000 - loss: 4.4230e-04 - val_accuracy: 0.7889 - val_loss: 1.3778
# [LSTM] Test Accuracy: 0.761

# %%
h_gru = fit_model(gru_model, "GRU")
show_result(gru_model, h_gru, "GRU")
# Out:
# Epoch 1/30
# 53/53 - 2s - 44ms/step - accuracy: 0.4548 - loss: 1.0259 - val_accuracy: 0.5583 - val_loss: 0.8045
# Epoch 2/30
# 53/53 - 1s - 14ms/step - accuracy: 0.6333 - loss: 0.6635 - val_accuracy: 0.6028 - val_loss: 0.7557
# Epoch 3/30
# 53/53 - 1s - 14ms/step - accuracy: 0.7101 - loss: 0.5394 - val_accuracy: 0.6389 - val_loss: 0.7737
# Epoch 4/30
# 53/53 - 1s - 13ms/step - accuracy: 0.8012 - loss: 0.4128 - val_accuracy: 0.6861 - val_loss: 0.8268
# Epoch 5/30
# 53/53 - 1s - 14ms/step - accuracy: 0.9125 - loss: 0.2264 - val_accuracy: 0.7278 - val_loss: 1.0551
# Epoch 6/30
# 53/53 - 1s - 15ms/step - accuracy: 0.9631 - loss: 0.1160 - val_accuracy: 0.6917 - val_loss: 1.4094
# Epoch 7/30
# 53/53 - 1s - 13ms/step - accuracy: 0.9756 - loss: 0.0654 - val_accuracy: 0.7444 - val_loss: 1.1323
# Epoch 8/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9780 - loss: 0.0525 - val_accuracy: 0.7556 - val_loss: 1.1651
# Epoch 9/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9929 - loss: 0.0191 - val_accuracy: 0.7556 - val_loss: 1.1816
# Epoch 10/30
# 53/53 - 1s - 13ms/step - accuracy: 0.9982 - loss: 0.0076 - val_accuracy: 0.7694 - val_loss: 1.2153
# Epoch 11/30
# 53/53 - 1s - 12ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7778 - val_loss: 1.2766
# Epoch 12/30
# 53/53 - 1s - 13ms/step - accuracy: 1.0000 - loss: 4.8515e-04 - val_accuracy: 0.7722 - val_loss: 1.3314
# [GRU] Test Accuracy: 0.669

# %% [markdown]
# ## 5. 6개 모델 성능 비교
#
# `res.json` 파일을 전혀 쓰지 않습니다. 지금까지 이 세션에서 쌓아온 `res` 딕셔너리를 바로 씁니다.

# %%
h_flat = fit_model(flat_model, "Flatten")
show_result(flat_model, h_flat, "Flatten")
# Out:
# Epoch 1/30
# 53/53 - 1s - 18ms/step - accuracy: 0.3905 - loss: 1.0812 - val_accuracy: 0.5278 - val_loss: 1.0357
# Epoch 2/30
# 53/53 - 0s - 5ms/step - accuracy: 0.8464 - loss: 0.6799 - val_accuracy: 0.7306 - val_loss: 0.6361
# Epoch 3/30
# 53/53 - 0s - 6ms/step - accuracy: 0.9750 - loss: 0.1198 - val_accuracy: 0.7417 - val_loss: 0.5858
# Epoch 4/30
# 53/53 - 0s - 6ms/step - accuracy: 0.9988 - loss: 0.0147 - val_accuracy: 0.7417 - val_loss: 0.6336
# Epoch 5/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.7500 - val_loss: 0.6436
# Epoch 6/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7500 - val_loss: 0.6449
# Epoch 7/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7500 - val_loss: 0.6539
# Epoch 8/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.7500 - val_loss: 0.6647
# Epoch 9/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 9.3189e-04 - val_accuracy: 0.7472 - val_loss: 0.6744
# Epoch 10/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 7.3711e-04 - val_accuracy: 0.7500 - val_loss: 0.6831
# Epoch 11/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 5.9870e-04 - val_accuracy: 0.7500 - val_loss: 0.6912
# Epoch 12/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 4.9656e-04 - val_accuracy: 0.7500 - val_loss: 0.6985
# Epoch 13/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 4.1866e-04 - val_accuracy: 0.7528 - val_loss: 0.7053
# [Flatten] Test Accuracy: 0.792

# %%
h_gap = fit_model(gap_model, "GAP")
show_result(gap_model, h_gap, "GAP")
# Out:
# Epoch 1/30
# 53/53 - 1s - 18ms/step - accuracy: 0.4399 - loss: 1.0835 - val_accuracy: 0.5389 - val_loss: 1.0385
# Epoch 2/30
# 53/53 - 0s - 5ms/step - accuracy: 0.7214 - loss: 0.8415 - val_accuracy: 0.7222 - val_loss: 0.7193
# Epoch 3/30
# 53/53 - 0s - 5ms/step - accuracy: 0.9071 - loss: 0.4144 - val_accuracy: 0.7889 - val_loss: 0.5280
# Epoch 4/30
# 53/53 - 0s - 5ms/step - accuracy: 0.9619 - loss: 0.1661 - val_accuracy: 0.8000 - val_loss: 0.5033
# Epoch 5/30
# 53/53 - 0s - 5ms/step - accuracy: 0.9845 - loss: 0.0723 - val_accuracy: 0.7944 - val_loss: 0.5237
# Epoch 6/30
# 53/53 - 0s - 5ms/step - accuracy: 0.9958 - loss: 0.0336 - val_accuracy: 0.7972 - val_loss: 0.5674
# Epoch 7/30
# 53/53 - 0s - 5ms/step - accuracy: 0.9982 - loss: 0.0182 - val_accuracy: 0.7833 - val_loss: 0.6136
# Epoch 8/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.7778 - val_loss: 0.6503
# Epoch 9/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.7778 - val_loss: 0.6683
# Epoch 10/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.7889 - val_loss: 0.6759
# Epoch 11/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.7917 - val_loss: 0.6882
# Epoch 12/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.7917 - val_loss: 0.7034
# Epoch 13/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7917 - val_loss: 0.7169
# Epoch 14/30
# 53/53 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7917 - val_loss: 0.7293
# [GAP] Test Accuracy: 0.858

# %%
h_conv = fit_model(conv_model, "Conv1D")
show_result(conv_model, h_conv, "Conv1D")
# Out:
# Epoch 1/30
# 53/53 - 1s - 22ms/step - accuracy: 0.4560 - loss: 1.0655 - val_accuracy: 0.5667 - val_loss: 0.9932
# Epoch 2/30
# 53/53 - 0s - 6ms/step - accuracy: 0.7315 - loss: 0.7589 - val_accuracy: 0.6889 - val_loss: 0.6872
# Epoch 3/30
# 53/53 - 0s - 6ms/step - accuracy: 0.8792 - loss: 0.3841 - val_accuracy: 0.7722 - val_loss: 0.5419
# Epoch 4/30
# 53/53 - 0s - 6ms/step - accuracy: 0.9690 - loss: 0.1222 - val_accuracy: 0.8056 - val_loss: 0.5167
# Epoch 5/30
# 53/53 - 0s - 6ms/step - accuracy: 0.9988 - loss: 0.0277 - val_accuracy: 0.8028 - val_loss: 0.5271
# Epoch 6/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.7917 - val_loss: 0.5673
# Epoch 7/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8000 - val_loss: 0.5815
# Epoch 8/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7917 - val_loss: 0.5897
# Epoch 9/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8000 - val_loss: 0.6038
# Epoch 10/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8000 - val_loss: 0.6196
# Epoch 11/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 8.4260e-04 - val_accuracy: 0.7972 - val_loss: 0.6337
# Epoch 12/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 6.3574e-04 - val_accuracy: 0.7972 - val_loss: 0.6477
# Epoch 13/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 4.9449e-04 - val_accuracy: 0.7944 - val_loss: 0.6605
# Epoch 14/30
# 53/53 - 0s - 6ms/step - accuracy: 1.0000 - loss: 3.9452e-04 - val_accuracy: 0.7972 - val_loss: 0.6723
# [Conv1D] Test Accuracy: 0.847

# %%
names = list(res.keys())

table = pd.DataFrame({
    "모델": names,
    "Test Accuracy": [res[n]["test_acc"] for n in names],
}).set_index("모델")

print(table.round(3))
# Out:
#            Test Accuracy
# 모델
# SimpleRNN          0.808
# LSTM               0.761
# GRU                0.669
# Flatten            0.792
# GAP                0.858
# Conv1D             0.847

# %%
plt.figure(figsize=(7, 5))
plt.bar(table.index, table["Test Accuracy"])
plt.ylim(0, 1)
plt.title("모델별 테스트 정확도")
plt.ylabel("Accuracy")
for i, v in enumerate(table["Test Accuracy"]):
    plt.text(i, v + 0.01, f"{v:.3f}", ha="center")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
for n in names:
    plt.plot(res[n]["val_loss"], marker="o", markersize=3, label=n)
plt.title("모델별 val_loss")
plt.xlabel("Epoch"); plt.ylabel("val_loss")
plt.legend()
plt.tight_layout()
plt.show()

# %%
best = table["Test Accuracy"].idxmax()
print(f"가장 정확도가 높은 모델: {best} ({table.loc[best, 'Test Accuracy']:.3f})")
# Out:
# 가장 정확도가 높은 모델: GAP (0.858)

# %% [markdown]
# ## 정리
#
# - 이 노트북은 **하나의 Colab 세션 안에서** Flatten/GAP/Conv1D/SimpleRNN/LSTM/GRU 6개 모델을 전부
#   학습하고 바로 비교했습니다. `res.json` 같은 중간 파일을 주고받지 않았기 때문에, 세션이 바뀌어도
#   이전 결과가 사라져서 비교가 깨지는 문제가 없습니다.
# - 대신 노트북 하나를 끝까지 실행하는 시간이 길어집니다 — 중간에 런타임이 끊기면 처음부터 다시
#   실행해야 합니다.
# - 같은 조건(데이터 분할, 임베딩 차원, 학습 설정)에서 처리 방식만 다른 6개 모델을 비교했다는 점을
#   기억하세요. 파라미터 수는 모델마다 다르므로, 이는 절대적 성능 우열이 아니라 **처리 방식에 따른
#   차이를 관찰**한 것입니다.
