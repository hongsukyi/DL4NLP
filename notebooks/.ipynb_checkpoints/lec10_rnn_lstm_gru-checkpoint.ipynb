# %% [markdown]
# # Lab 3 · 6개 모델 한 번에 비교 (MLP·Conv1D·RNN 계열)
#
# - 6개 모델 (Flatten/GAP/Conv1D/SimpleRNN/LSTM/GRU)을 전부 정의 → 학습 → 비교합니다.
#
# - 모델마다 하이퍼파라미터(임베딩 차원 포함)가 따로 있어서 그 변수만 바꾸면 됩니다.

# %%
# !pip install -q koreanize-matplotlib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import koreanize_matplotlib

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers

from sklearn.metrics import confusion_matrix
from sklearn.manifold import TSNE

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## 1. 저장된 파일 불러오기

# %%
import urllib.request

url = "https://raw.githubusercontent.com/hongsukyi/DL4NLP/main/notebooks/data.npz"
urllib.request.urlretrieve(url, "data.npz")
# Out:
# ('data.npz', <http.client.HTTPMessage at 0x2618adbdc90>)

# %%
data = np.load("data.npz", allow_pickle=True)

ids = data["input_ids"]
y   = data["labels"]

idx_tr  = data["train_idx"]
idx_val = data["val_idx"]
idx_te  = data["test_idx"]

vocab_size = int(data["vocab_size"])
max_len    = int(data["max_len"])
n_cls      = int(data["num_classes"])
pad_id     = int(data["pad_id"])
classes    = data["class_names"].tolist()

X_tr,  y_tr  = ids[idx_tr],  y[idx_tr]
X_val, y_val = ids[idx_val], y[idx_val]
X_te,  y_te  = ids[idx_te],  y[idx_te]

print("train/val/test:", len(X_tr), len(X_val), len(X_te))
print("classes:", classes)

# Embedding(mask_zero=True)는 "PAD의 토큰 ID가 0"이라고 가정합니다. 실제로 그런지 확인합니다.
assert pad_id == 0, f"pad_id가 0이 아닙니다({pad_id}). mask_zero=True를 그대로 쓰면 안 됩니다."
print("pad_id:", pad_id, "-> mask_zero=True 사용 가능")
# Out:
# train/val/test: 1680 360 360
# classes: ['면접', '학교', '협상']
# pad_id: 0 -> mask_zero=True 사용 가능

# %% [markdown]
# ## 2. 공통 준비물 + 모델별 하이퍼파라미터

# %%
res = {}  # 6개 모델 결과 (파일 저장 없이 메모리에만)

emb_dim = 128  # 임베딩 차원 (6개 모델 공통)

# ---- 모델별 하이퍼파라미터 ----
rnn_units    = 64
lstm_units   = 64
gru_units    = 64

#-----------------------
flat_dense   = 64
gap_dense    = 64
conv_filters = 64
conv_kernel  = 3

# %%
def fit_model(model, name):
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    es = keras.callbacks.EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True)
    h = model.fit(
        X_tr, y_tr, validation_data=(X_val, y_val),
        batch_size=32, epochs=30, callbacks=[es], verbose=2,
    )
    return h

# %%
def show_result(model, h, name):
    fig, ax = plt.subplots(1, 2, figsize=(10, 3))
    ax[0].plot(h.history["loss"], label="train"); ax[0].plot(h.history["val_loss"], label="val")
    ax[0].set_title(f"{name} - Loss"); ax[0].legend()
    ax[1].plot(h.history["accuracy"], label="train"); ax[1].plot(h.history["val_accuracy"], label="val")
    ax[1].set_title(f"{name} - Accuracy"); ax[1].legend()
    plt.tight_layout(); plt.show()

    pred = model.predict(X_te, verbose=0).argmax(axis=1)
    acc = (pred == y_te).mean()
    res[name] = {
        "loss": h.history["loss"], "val_loss": h.history["val_loss"],
        "acc": h.history["accuracy"], "val_acc": h.history["val_accuracy"],
        "pred": pred.tolist(), "test_acc": float(acc),
    }
    print(f"[{name}] Test Accuracy: {acc:.3f}")

    cm = confusion_matrix(y_te, pred)
    plt.figure(figsize=(4, 4))
    plt.imshow(cm, cmap="Blues")
    plt.xticks(range(n_cls), classes); plt.yticks(range(n_cls), classes)
    for i in range(n_cls):
        for j in range(n_cls):
            plt.text(j, i, cm[i, j], ha="center", va="center")
    plt.title(f"{name} - Confusion Matrix"); plt.xlabel("예측"); plt.ylabel("정답")
    plt.tight_layout(); plt.show()

    feat_model = keras.Model(model.input, model.get_layer("feat").output)
    feat = feat_model.predict(X_te, verbose=0)
    xy = TSNE(n_components=2, random_state=SEED, init="pca", perplexity=30, n_jobs=1).fit_transform(feat)

    plt.figure(figsize=(5, 3))
    for c in range(n_cls):
        m = y_te == c
        plt.scatter(xy[m, 0], xy[m, 1], s=12, label=classes[c])
    plt.title(f"{name} - t-SNE"); plt.legend()
    plt.tight_layout(); plt.show()

# %% [markdown]
# ## 3. 모델 정의하기
#
# - Embedding(..., mask_zero=True) 한 줄로 PAD 처리가 끝납니다.
# - GAP은 GlobalAveragePooling1D()가, SimpleRNN/LSTM/GRU는 각 층 자체가 마스크를 자동으로 존중합니다.
# - Conv1D만 마스킹을 지원하지 않기 때문에 keras.ops로 직접 계산한 값을 더해서 PAD를 밀어냅니다.

# %%
def build_flatten():
    inp = keras.Input((max_len,))
    x = layers.Embedding(vocab_size, emb_dim, mask_zero=True)(inp)
    x = layers.Flatten()(x)
    x = layers.Dense(flat_dense, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)
    return keras.Model(inp, out)

flat_model = build_flatten()
flat_model.summary()
# Out:
# C:\Users\hongs\anaconda3\envs\qml44\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'flatten' (of type Flatten) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, 32, 128)             │       4,096,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         262,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ feat (Dense)                         │ (None, 16)                  │           1,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,359,299 (16.63 MB)
#  Trainable params: 4,359,299 (16.63 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def build_gap():
    inp = keras.Input((max_len,))
    x = layers.Embedding(vocab_size, emb_dim, mask_zero=True)(inp)
    x = layers.GlobalAveragePooling1D()(x)                   # PAD 제외 평균이 자동으로 계산됨
    x = layers.Dense(  gap_dense, activation="relu", )(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)
    return keras.Model(inp, out)

gap_model = build_gap()
gap_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 32)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_1 (Embedding)       │ (None, 32, 128)           │       4,096,000 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ not_equal_1 (NotEqual)        │ (None, 32)                │               0 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 128)               │               0 │ embedding_1[0][0],         │
# │ (GlobalAveragePooling1D)      │                           │                 │ not_equal_1[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 64)                │           8,256 │ global_average_pooling1d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ feat (Dense)                  │ (None, 16)                │           1,040 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 3)                 │              51 │ feat[0][0]                 │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,105,347 (15.66 MB)
#  Trainable params: 4,105,347 (15.66 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def build_conv1d():
    inp = keras.Input((max_len,))
    x = layers.Embedding(vocab_size, emb_dim, mask_zero=True)(inp)
    x = layers.Conv1D(conv_filters, kernel_size=conv_kernel, padding="same", activation="relu")(x)
    x = layers.SpatialDropout1D(0.3)(x)   # 과적합 방지: 채널(필터) 단위로 통째로 끔

    # Conv1D는 mask를 지원하지 않으므로, PAD 위치를 직접 아주 작은 값으로 밀어냅니다.
    # 주의: inp는 토큰 ID(0, 1521, 3960 ...)이지 0/1 마스크가 아닙니다.
    # 반드시 "0인지 아닌지"를 먼저 판별해서 0/1로 만든 뒤에 사용해야 합니다.
    is_pad = keras.ops.cast(keras.ops.equal(inp, 0), "float32")
    bias = is_pad[..., None] * -1e9
    x = x + bias

    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)
    return keras.Model(inp, out)

conv_model = build_conv1d()
conv_model.summary()
# Out:
# C:\Users\hongs\anaconda3\envs\qml44\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'conv1d' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 32)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ equal (Equal)                 │ (None, 32)                │               0 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_2 (Embedding)       │ (None, 32, 128)           │       4,096,000 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ cast (Cast)                   │ (None, 32)                │               0 │ equal[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 32, 64)            │          24,640 │ embedding_2[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ get_item (GetItem)            │ (None, 32, 1)             │               0 │ cast[0][0]                 │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ spatial_dropout1d             │ (None, 32, 64)            │               0 │ conv1d[0][0]               │
# │ (SpatialDropout1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply (Multiply)           │ (None, 32, 1)             │               0 │ get_item[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 64)            │               0 │ spatial_dropout1d[0][0],   │
# │                               │                           │                 │ multiply[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_max_pooling1d          │ (None, 64)                │               0 │ add[0][0]                  │
# │ (GlobalMaxPooling1D)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_4 (Dense)               │ (None, 64)                │           4,160 │ global_max_pooling1d[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ feat (Dense)                  │ (None, 16)                │           1,040 │ dense_4[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_5 (Dense)               │ (None, 3)                 │              51 │ feat[0][0]                 │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,125,891 (15.74 MB)
#  Trainable params: 4,125,891 (15.74 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def build_simplernn():
    inp = keras.Input((max_len,))
    x = layers.Embedding(vocab_size, emb_dim, mask_zero=True)(inp)
    x = layers.SimpleRNN(rnn_units, recurrent_dropout=0.3)(x)   # 과적합 방지: 순환 연결에 dropout
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)
    return keras.Model(inp, out)

rnn_model = build_simplernn()
rnn_model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)    │ (None, 32)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_4 (Embedding)       │ (None, 32, 128)           │       4,096,000 │ input_layer_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ not_equal_4 (NotEqual)        │ (None, 32)                │               0 │ input_layer_4[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ simple_rnn_1 (SimpleRNN)      │ (None, 64)                │          12,352 │ embedding_4[0][0],         │
# │                               │                           │                 │ not_equal_4[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_8 (Dense)               │ (None, 64)                │           4,160 │ simple_rnn_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ feat (Dense)                  │ (None, 16)                │           1,040 │ dense_8[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 3)                 │              51 │ feat[0][0]                 │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,113,603 (15.69 MB)
#  Trainable params: 4,113,603 (15.69 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def build_lstm():
    inp = keras.Input((max_len,))
    x = layers.Embedding(vocab_size, emb_dim, mask_zero=True)(inp)
    x = layers.LSTM(lstm_units, dropout=0.3)(x)   # 과적합 방지: 입력->게이트 연결에 dropout
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)
    return keras.Model(inp, out)

lstm_model = build_lstm()
lstm_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)    │ (None, 32)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_5 (Embedding)       │ (None, 32, 128)           │       4,096,000 │ input_layer_5[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ not_equal_5 (NotEqual)        │ (None, 32)                │               0 │ input_layer_5[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ (None, 64)                │          49,408 │ embedding_5[0][0],         │
# │                               │                           │                 │ not_equal_5[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 64)                │           4,160 │ lstm[0][0]                 │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ feat (Dense)                  │ (None, 16)                │           1,040 │ dense_10[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 3)                 │              51 │ feat[0][0]                 │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,150,659 (15.83 MB)
#  Trainable params: 4,150,659 (15.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def build_gru():
    inp = keras.Input((max_len,))
    x = layers.Embedding(vocab_size, emb_dim, mask_zero=True)(inp)
    x = layers.GRU(gru_units, recurrent_dropout=0.3)(x)   # 과적합 방지: 순환 상태에 dropout
    x = layers.Dense(64, activation="relu")(x)
    feat = layers.Dense(16, activation="relu", name="feat")(x)
    out = layers.Dense(n_cls, activation="softmax")(feat)
    return keras.Model(inp, out)

gru_model = build_gru()
gru_model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)    │ (None, 32)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_6 (Embedding)       │ (None, 32, 128)           │       4,096,000 │ input_layer_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ not_equal_6 (NotEqual)        │ (None, 32)                │               0 │ input_layer_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ gru (GRU)                     │ (None, 64)                │          37,248 │ embedding_6[0][0],         │
# │                               │                           │                 │ not_equal_6[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 64)                │           4,160 │ gru[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ feat (Dense)                  │ (None, 16)                │           1,040 │ dense_12[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 3)                 │              51 │ feat[0][0]                 │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,138,499 (15.79 MB)
#  Trainable params: 4,138,499 (15.79 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 4. 델 이어서 학습하기
#
# - model.fit()을 여섯 번 이어서 실행합니다.

# %%
h_rnn = fit_model(rnn_model, "SimpleRNN")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/30
# 53/53 - 2s - 40ms/step - accuracy: 0.3643 - loss: 1.0968 - val_accuracy: 0.4306 - val_loss: 1.0811
# Epoch 2/30
# 53/53 - 1s - 13ms/step - accuracy: 0.4155 - loss: 1.0744 - val_accuracy: 0.4639 - val_loss: 1.0318
# Epoch 3/30
# 53/53 - 1s - 12ms/step - accuracy: 0.4839 - loss: 0.9998 - val_accuracy: 0.5333 - val_loss: 0.8958
# Epoch 4/30
# 53/53 - 1s - 12ms/step - accuracy: 0.5619 - loss: 0.8463 - val_accuracy: 0.5500 - val_loss: 0.8318
# Epoch 5/30
# 53/53 - 1s - 12ms/step - accuracy: 0.6214 - loss: 0.7417 - val_accuracy: 0.5556 - val_loss: 0.8260
# Epoch 6/30
# 53/53 - 1s - 12ms/step - accuracy: 0.6423 - loss: 0.7083 - val_accuracy: 0.5778 - val_loss: 0.8356
# Epoch 7/30
# 53/53 - 1s - 13ms/step - accuracy: 0.6679 - loss: 0.6759 - val_accuracy: 0.5694 - val_loss: 0.8278
# Epoch 8/30
# 53/53 - 1s - 12ms/step - accuracy: 0.6958 - loss: 0.6271 - val_accuracy: 0.6333 - val_loss: 0.7671
# Epoch 9/30
# 53/53 - 1s - 12ms/step - accuracy: 0.7333 - loss: 0.5963 - val_accuracy: 0.6833 - val_loss: 0.7541
# Epoch 10/30
# 53/53 - 1s - 12ms/step - accuracy: 0.7810 - loss: 0.5266 - val_accuracy: 0.6944 - val_loss: 0.7326
# Epoch 11/30
# 53/53 - 1s - 12ms/step - accuracy: 0.8125 - loss: 0.4823 - val_accuracy: 0.7389 - val_loss: 0.7077
# Epoch 12/30
# 53/53 - 1s - 12ms/step - accuracy: 0.8357 - loss: 0.4173 - val_accuracy: 0.7389 - val_loss: 0.7528
# Epoch 13/30
# 53/53 - 1s - 13ms/step - accuracy: 0.8738 - loss: 0.3521 - val_accuracy: 0.7194 - val_loss: 0.8149
# Epoch 14/30
# 53/53 - 1s - 12ms/step - accuracy: 0.8851 - loss: 0.3224 - val_accuracy: 0.7333 - val_loss: 0.8354
# Epoch 15/30
# 53/53 - 1s - 12ms/step - accuracy: 0.8988 - loss: 0.2832 - val_accuracy: 0.7500 - val_loss: 0.8618
# Epoch 16/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9208 - loss: 0.2382 - val_accuracy: 0.7472 - val_loss: 0.9527
# Epoch 17/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9077 - loss: 0.2556 - val_accuracy: 0.7444 - val_loss: 0.9127
# Epoch 18/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9351 - loss: 0.1963 - val_accuracy: 0.7694 - val_loss: 0.9575
# Epoch 19/30
# 53/53 - 1s - 12ms/step - accuracy: 0.9363 - loss: 0.1840 - val_accuracy: 0.7611 - val_loss: 1.0588

# %%
h_lstm = fit_model(lstm_model, "LSTM")
# Out:
# Epoch 1/30
# 53/53 - 3s - 51ms/step - accuracy: 0.5161 - loss: 1.0046 - val_accuracy: 0.6278 - val_loss: 0.7695
# Epoch 2/30
# 53/53 - 1s - 16ms/step - accuracy: 0.8310 - loss: 0.4659 - val_accuracy: 0.7639 - val_loss: 0.6108
# Epoch 3/30
# 53/53 - 1s - 16ms/step - accuracy: 0.9482 - loss: 0.1676 - val_accuracy: 0.7861 - val_loss: 0.6794
# Epoch 4/30
# 53/53 - 1s - 16ms/step - accuracy: 0.9744 - loss: 0.0856 - val_accuracy: 0.8111 - val_loss: 0.6492
# Epoch 5/30
# 53/53 - 1s - 17ms/step - accuracy: 0.9905 - loss: 0.0380 - val_accuracy: 0.7861 - val_loss: 0.8058
# Epoch 6/30
# 53/53 - 1s - 15ms/step - accuracy: 0.9952 - loss: 0.0190 - val_accuracy: 0.7972 - val_loss: 0.8401
# Epoch 7/30
# 53/53 - 1s - 16ms/step - accuracy: 0.9946 - loss: 0.0174 - val_accuracy: 0.7833 - val_loss: 1.0063
# Epoch 8/30
# 53/53 - 1s - 16ms/step - accuracy: 0.9970 - loss: 0.0111 - val_accuracy: 0.7972 - val_loss: 0.9320
# Epoch 9/30
# 53/53 - 1s - 16ms/step - accuracy: 0.9994 - loss: 0.0046 - val_accuracy: 0.8056 - val_loss: 1.0087
# Epoch 10/30
# 53/53 - 1s - 16ms/step - accuracy: 0.9982 - loss: 0.0088 - val_accuracy: 0.7833 - val_loss: 1.0707

# %%
h_gru = fit_model(gru_model, "GRU")
# Out:
# Epoch 1/30
# 53/53 - 3s - 55ms/step - accuracy: 0.5292 - loss: 0.9989 - val_accuracy: 0.5778 - val_loss: 0.8048
# Epoch 2/30
# 53/53 - 1s - 18ms/step - accuracy: 0.6821 - loss: 0.6511 - val_accuracy: 0.6500 - val_loss: 0.7130
# Epoch 3/30
# 53/53 - 1s - 18ms/step - accuracy: 0.8012 - loss: 0.4579 - val_accuracy: 0.6944 - val_loss: 0.7428
# Epoch 4/30
# 53/53 - 1s - 18ms/step - accuracy: 0.8827 - loss: 0.3018 - val_accuracy: 0.7056 - val_loss: 0.8365
# Epoch 5/30
# 53/53 - 1s - 17ms/step - accuracy: 0.9036 - loss: 0.2487 - val_accuracy: 0.7361 - val_loss: 0.8298
# Epoch 6/30
# 53/53 - 1s - 18ms/step - accuracy: 0.9214 - loss: 0.2143 - val_accuracy: 0.6750 - val_loss: 1.0214
# Epoch 7/30
# 53/53 - 1s - 18ms/step - accuracy: 0.9595 - loss: 0.1170 - val_accuracy: 0.7833 - val_loss: 0.8997
# Epoch 8/30
# 53/53 - 1s - 18ms/step - accuracy: 0.9786 - loss: 0.0621 - val_accuracy: 0.7750 - val_loss: 0.9718
# Epoch 9/30
# 53/53 - 1s - 18ms/step - accuracy: 0.9857 - loss: 0.0415 - val_accuracy: 0.7778 - val_loss: 0.9820
# Epoch 10/30
# 53/53 - 1s - 18ms/step - accuracy: 0.9917 - loss: 0.0264 - val_accuracy: 0.7806 - val_loss: 1.0268

# %% [markdown]
# ## 5. 결과 확인

# %%
show_result(rnn_model, h_rnn, "SimpleRNN")
# Out:
# [SimpleRNN] Test Accuracy: 0.797

# %%
show_result(lstm_model, h_lstm, "LSTM")
# Out:
# [LSTM] Test Accuracy: 0.803

# %%
show_result(gru_model, h_gru, "GRU")
# Out:
# [GRU] Test Accuracy: 0.742

# %% [markdown]
# ## 이전 모델 학습 : 복습

# %%
h_flat = fit_model(flat_model, "Flatten")
# Out:
# Epoch 1/30
# C:\Users\hongs\anaconda3\envs\qml44\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'flatten' (of type Flatten) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 53/53 - 1s - 22ms/step - accuracy: 0.4167 - loss: 1.0704 - val_accuracy: 0.5222 - val_loss: 1.0008
# Epoch 2/30
# 53/53 - 0s - 9ms/step - accuracy: 0.7381 - loss: 0.6908 - val_accuracy: 0.7000 - val_loss: 0.6493
# Epoch 3/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9530 - loss: 0.1867 - val_accuracy: 0.7583 - val_loss: 0.5394
# Epoch 4/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9982 - loss: 0.0271 - val_accuracy: 0.7500 - val_loss: 0.6054
# Epoch 5/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7611 - val_loss: 0.6009
# Epoch 6/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7778 - val_loss: 0.6245
# Epoch 7/30
# 53/53 - 1s - 10ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.7806 - val_loss: 0.6459
# Epoch 8/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.7611 - val_loss: 0.6423
# Epoch 9/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 7.0886e-04 - val_accuracy: 0.7694 - val_loss: 0.6391
# Epoch 10/30
# 53/53 - 1s - 10ms/step - accuracy: 1.0000 - loss: 4.9811e-04 - val_accuracy: 0.7611 - val_loss: 0.6429
# Epoch 11/30
# 53/53 - 1s - 10ms/step - accuracy: 1.0000 - loss: 3.6537e-04 - val_accuracy: 0.7667 - val_loss: 0.6501

# %%
h_gap = fit_model(gap_model, "GAP")
# Out:
# Epoch 1/30
# 53/53 - 1s - 23ms/step - accuracy: 0.5667 - loss: 1.0617 - val_accuracy: 0.6778 - val_loss: 0.9721
# Epoch 2/30
# 53/53 - 0s - 9ms/step - accuracy: 0.8256 - loss: 0.6895 - val_accuracy: 0.7417 - val_loss: 0.6131
# Epoch 3/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9280 - loss: 0.2776 - val_accuracy: 0.7806 - val_loss: 0.5176
# Epoch 4/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9768 - loss: 0.1026 - val_accuracy: 0.7972 - val_loss: 0.5343
# Epoch 5/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9952 - loss: 0.0408 - val_accuracy: 0.7861 - val_loss: 0.5616
# Epoch 6/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9982 - loss: 0.0182 - val_accuracy: 0.7944 - val_loss: 0.6151
# Epoch 7/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.7944 - val_loss: 0.6510
# Epoch 8/30
# 53/53 - 1s - 10ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7917 - val_loss: 0.6834
# Epoch 9/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.7861 - val_loss: 0.6974
# Epoch 10/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7889 - val_loss: 0.7077
# Epoch 11/30
# 53/53 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.7778 - val_loss: 0.7241

# %%
h_conv = fit_model(conv_model, "Conv1D")
# Out:
# Epoch 1/30
# C:\Users\hongs\anaconda3\envs\qml44\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'conv1d' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 53/53 - 1s - 26ms/step - accuracy: 0.4542 - loss: 1.0658 - val_accuracy: 0.5667 - val_loss: 0.9694
# Epoch 2/30
# 53/53 - 1s - 10ms/step - accuracy: 0.6577 - loss: 0.7700 - val_accuracy: 0.6639 - val_loss: 0.7210
# Epoch 3/30
# 53/53 - 1s - 10ms/step - accuracy: 0.8298 - loss: 0.4937 - val_accuracy: 0.7861 - val_loss: 0.5436
# Epoch 4/30
# 53/53 - 1s - 10ms/step - accuracy: 0.9262 - loss: 0.2173 - val_accuracy: 0.8083 - val_loss: 0.4906
# Epoch 5/30
# 53/53 - 1s - 10ms/step - accuracy: 0.9732 - loss: 0.0907 - val_accuracy: 0.8167 - val_loss: 0.5192
# Epoch 6/30
# 53/53 - 1s - 10ms/step - accuracy: 0.9857 - loss: 0.0538 - val_accuracy: 0.8444 - val_loss: 0.5028
# Epoch 7/30
# 53/53 - 1s - 9ms/step - accuracy: 0.9970 - loss: 0.0214 - val_accuracy: 0.8389 - val_loss: 0.5168
# Epoch 8/30
# 53/53 - 1s - 9ms/step - accuracy: 0.9964 - loss: 0.0129 - val_accuracy: 0.8167 - val_loss: 0.5985
# Epoch 9/30
# 53/53 - 1s - 9ms/step - accuracy: 0.9976 - loss: 0.0136 - val_accuracy: 0.8194 - val_loss: 0.6521
# Epoch 10/30
# 53/53 - 1s - 9ms/step - accuracy: 0.9982 - loss: 0.0110 - val_accuracy: 0.8167 - val_loss: 0.6813
# Epoch 11/30
# 53/53 - 0s - 9ms/step - accuracy: 0.9994 - loss: 0.0071 - val_accuracy: 0.8056 - val_loss: 0.7366
# Epoch 12/30
# 53/53 - 1s - 10ms/step - accuracy: 0.9994 - loss: 0.0051 - val_accuracy: 0.8250 - val_loss: 0.6907

# %%
show_result(flat_model, h_flat, "Flatten")
# Out:
# [Flatten] Test Accuracy: 0.814
# C:\Users\hongs\anaconda3\envs\qml44\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'flatten' (of type Flatten) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(

# %%
show_result(gap_model, h_gap, "GAP")
# Out:
# [GAP] Test Accuracy: 0.850

# %%
show_result(conv_model, h_conv, "Conv1D")
# Out:
# [Conv1D] Test Accuracy: 0.856
# C:\Users\hongs\anaconda3\envs\qml44\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'conv1d' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(

# %% [markdown]
# ## 6. 6개 모델 성능 비교

# %%
names = list(res.keys())

table = pd.DataFrame({
    "모델": names,
    "Test Accuracy": [res[n]["test_acc"] for n in names],
}).set_index("모델")

print(table.round(3))
# Out:
#            Test Accuracy
# 모델
# SimpleRNN          0.797
# LSTM               0.803
# GRU                0.742
# Flatten            0.814
# GAP                0.850
# Conv1D             0.856

# %%
plt.figure(figsize=(7, 4))
plt.bar(table.index, table["Test Accuracy"])
plt.ylim(0, 1)
plt.title("모델별 테스트 정확도")
plt.ylabel("Accuracy")
for i, v in enumerate(table["Test Accuracy"]):
    plt.text(i, v + 0.01, f"{v:.3f}", ha="center")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
for n in names:
    plt.plot(res[n]["val_loss"], marker="o", markersize=3, label=n)
plt.title("모델별 val_loss")
plt.xlabel("Epoch"); plt.ylabel("val_loss")
plt.legend()
plt.tight_layout()
plt.show()

# %%
best = table["Test Accuracy"].idxmax()
print(f"가장 정확도가 높은 모델: {best} ({table.loc[best, 'Test Accuracy']:.3f})")
# Out:
# 가장 정확도가 높은 모델: Conv1D (0.856)

# %% [markdown]
# ## 정리
#
# `emb_dim`(임베딩 차원)은 6개 모델 공통(128)이고, 나머지는 모델마다 다릅니다.
#
# | 모델 | 하이퍼파라미터 |
# |---|---|
# | Flatten | `flat_dense` |
# | GAP | `gap_dense` |
# | Conv1D | `conv_filters`, `conv_kernel` |
# | SimpleRNN | `rnn_units` |
# | LSTM | `lstm_units` |
# | GRU | `gru_units` |
#
# - 이 결과는 절대적 성능 우열이 아니라, 같은 데이터·같은 조건에서 처리 방식에 따른 차이를
#   관찰한 것입니다.
